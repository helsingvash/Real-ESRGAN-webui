# %%
# !git clone https://github.com/coderxi1/Real-ESRGAN-webui.git --recurse-submodules

# Instalar pacotes necessários
# !pip install basicsr facexlib gfpgan gradio ffmpeg ffmpeg-python
# !sudo apt update && sudo apt install ffmpeg -y

# Entrar no diretório Real-ESRGAN-webui e instalar dependências
# !cd Real-ESRGAN-webui && pip install -r Real-ESRGAN/requirements.txt && python Real-ESRGAN/setup.py develop

# Aplicar correções no código
# !sed -i 's/from torchvision.transforms.functional_tensor import rgb_to_grayscale/from torchvision.transforms.functional import rgb_to_grayscale/' $(find / -type f -name "degradations.py" 2>/dev/null)
# !sed -i 's/\.style(height=300)//g' Real-ESRGAN-webui/webui.py
# !sed -i '/with open.*VERSION.*/d' ~/Real-ESRGAN-webui/Real-ESRGAN/setup.py
# !ln -s /tmp/gradio/ ~/gradio_tmp
# !rm -rf /tmp/gradio/*
# !sed -i "s|output_dir = osp.dirname(video_path)|output_dir = osp.join(osp.dirname(__file__), 'output')|" ~/Real-ESRGAN-webui/webui.py
# !mkdir -p ~/Real-ESRGAN-webui/output
# Executar o webui.py corretamente dentro do diretório
# !cd Real-ESRGAN-webui && python webui.py --share
# Out:
# fatal: destination path 'Real-ESRGAN-webui' already exists and is not an empty directory.
#
#
# ⚡️ Tip	Connect GitHub to Studios: https://lightning.ai/elderappstore/home?settings=integrations
#
# ...
# Hit:1 https://download.docker.com/linux/ubuntu focal InRelease
# Get:2 https://cli.github.com/packages stable InRelease [3917 B]
# Hit:3 https://nvidia.github.io/libnvidia-container/stable/deb/amd64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Fetched 132 kB in 1s (198 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 16 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# ...

# %%
# !cd Real-ESRGAN-webui && python webui.py --share
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://f702bb1b2cd1acc00b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# output: /teamspace/studios/this_studio/Real-ESRGAN-webui/output/onepiece_demo_2x.RealESRGAN_x2plus.mp4
# inference: 100%|███████████████████████████| 181/181 [00:36<00:00,  4.96frame/s]
# ^C
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://f702bb1b2cd1acc00b.gradio.live

# %%
# !rm -rf /tmp/gradio/*

# %%
# !df -h ~
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         549G   42G  480G   8% /teamspace/studios/this_studio
